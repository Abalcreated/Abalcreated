# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import drive 
drive.mount("/content/drive")
from matplotlib import pyplot as plt
# Out:
# Mounted at /content/drive

# %%
image = cv2.imread("/content/drive/MyDrive/UTS_iqbal.jpeg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1600 at 0x7FCFD8629B10>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "collapsed_sections": [],
      "mount_file_id": "1ryaxNBfZRvrpjJ775bhpdoBbSKHCY4tV",
      "authorship_tag": "ABX9TyPzLV7ixIqX5bCCEjNWjPVw",
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    },
    "accelerator": "GPU",
    "gpuClass": "standard"
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/iljimae13/UTS/blob/main/SoalUTSGenapB.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 1,
      "metadata": {
        "id": "SqxVaZBKO40M"
      },
      "outputs": [],
      "source": [
        "import cv2 as cv\n",
        "import numpy as np\n",
        "import matplotlib.pyplot as plt\n",
        "\n",
        "from google.colab.patches import cv2_imshow\n",
        "from skimage import io\n",
        "from PIL import Image"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#link image\n",
        "url =\"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSrFmGz7YhwkJaj_7e8xur_cDY1ynPEaZstlg&usqp=CAU\"\n",
        "\n",
        "image = io.imread(url)\n",
        "image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)\n",
        "final_frame = cv.hconcat((image, image_2))\n",
        "cv2_imshow "
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "vzQZ2SVSL5RK",
        "outputId": "c4d28b87-c6ea-49af-bd6b-697ca93c09ff"
      },
      "execution_count": 4,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=RGB size=450x225 at 0x7FE51E3FB890>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
    },
    {
      "cell_type": "code",
      "source": [
        "print(image.size)\n",
        "print(image.shape)\n",
        "print(image.dtype)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "DJ-YC5cwPXQR",
        "outputId": "97c0cc4c-526c-4c1e-d800-1332fb6c386c"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "151875\n",
            "(225, 225, 3)\n",
            "uint8\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "import numpy as np\n",
        "a = np.array([[1,2,2,2,10],[10,20,30,40,50]])\n",
        "print(a)\n",
        "print(a.ravel())\n",
        "print(a.flatten())\n",
        "plt.hist(a.ravel(),bins = 50, range = [0,50])\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 334
        },
        "id": "5naCf2ZLXEPU",
        "outputId": "156ff621-c1bd-4627-d905-6eae1e9d37b1"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "[[ 1  2  2  2 10]\n",
            " [10 20 30 40 50]]\n",
            "[ 1  2  2  2 10 10 20 30 40 50]\n",
            "[ 1  2  2  2 10 10 20 30 40 50]\n"
          ]
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(image.ravel(), bins = 256, range = [0,256])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "Rs3IW5MLXJSn",
        "outputId": "b3f7c562-00dd-4910-8109-258b586bf68e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "color = ('b','g','r')\n",
        "for i,col in enumerate(color):\n",
        "  histogr = cv.calcHist([image], [i], None, [256], [0,256])\n",
        "  plt.plot(histogr, color = col)\n",
        "  plt.xlim([0,256])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "AMU23z0yXNBt",
        "outputId": "2c299bd9-31f4-4e61-b40c-a73d347e37ff"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "color = ('b','g','r')\n",
        "for i,col in enumerate(color):\n",
        "  histogr = cv.calcHist([image], [i], None, [4], [0,256])\n",
        "  plt.plot(histogr, color = col)\n",
        "  plt.xlim([0,4])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "8vSS19EcXT6N",
        "outputId": "693a51bb-a1c5-4eb2-eb4e-cf5f8e140bb0"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "color = ('c','d','r')\n",
        "for i,col in enumerate(color):\n",
        "  histogr = cv.calcHist([image], [i], None, [8], [0,256])\n",
        "  plt.plot(histogr, color = col)\n",
        "  plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 764
        },
        "id": "we8UtiCWXXXR",
        "outputId": "a85e3f23-bc30-416f-af92-ba74877054ed"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "color = ('b','g','r')\n",
        "for i,col in enumerate(color):\n",
        "  histogr = cv.calcHist([image], [i], None, [16], [0,256])\n",
        "  plt.plot(histogr, color = col)\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "gCxV1B9RXZb4",
        "outputId": "4143b92c-6bcd-47e3-ad38-e3ebbda78d18"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "color = ('b','g','r')\n",
        "for i,col in enumerate(color):\n",
        "  histogr = cv.calcHist([image], [i], None, [32], [0,256])\n",
        "  plt.plot(histogr, color = col)\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "goH0hIhqXhHc",
        "outputId": "e1caeb0c-bf20-40ed-a978-a385345f4eab"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "b,g,r = cv.split(image)\n",
        "cv2_imshow(b)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "8QCtHCjpXkiI",
        "outputId": "7eb1ab24-ebcb-471b-cfc7-3235933d0199"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC429F0E550>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "image = io.imread(url)\n",
        "\n",
        "#blue channel\n",
        "bluech = image[:,:,0]\n",
        "cv2_imshow(bluech)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "sM3YsJA5XmQv",
        "outputId": "3aaf2f9b-f83c-47ee-a903-cb762bc7ee69"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC429EC4550>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 16, [0, 256], color='blue')\n",
        "plt.xlabel('Bins 16')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "LDbLAbYpXqTm",
        "outputId": "e53477a4-2e0a-4f6c-9277-e2f66d08ddd9"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 8, [0, 256], color='blue')\n",
        "plt.xlabel('Bins 32')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "i---ZUQuXtTN",
        "outputId": "df912c31-4c5f-46c9-ccd3-0677ecc58027"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 32, [0, 256], color='blue')\n",
        "plt.xlabel('Bins 8')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "8K_wZxSbXxLH",
        "outputId": "f0578de5-8f9b-469d-8141-73bf19b0202e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 256, [0, 256], color='blue')\n",
        "plt.xlabel('Bins 256')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "08HDfroJX0yG",
        "outputId": "cffe8886-3f5a-4ace-a1d9-0b08971d7c27"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 4, [0, 256], color='blue')\n",
        "plt.xlabel('Bins 4')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "tqkqhKlHX5q6",
        "outputId": "8b2b803f-9434-4012-8b4b-f983da1c9a2a"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#green channel\n",
        "greench = image[:,:,1]\n",
        "cv2_imshow(greench)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "_FXJ2bjuX7AB",
        "outputId": "9715558f-fe50-42c6-8e5f-a8237669f68e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC42A02A090>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 8, [0, 256], color='green')\n",
        "plt.xlabel('32')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "twW4zcZ7X910",
        "outputId": "0b7b1f93-0bd2-4baa-b669-b607479fdb59"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 4, [0, 256], color='green')\n",
        "plt.xlabel('Bins 4')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "UCnKH-VvYC9z",
        "outputId": "b264b77f-2ac4-47b5-ebd1-018864298a3d"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 16, [0, 256], color='green')\n",
        "plt.xlabel('Bins 16')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "4yc1qob_YFEq",
        "outputId": "9977cf95-4734-4434-e5f1-57f879733a1a"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 32, [0, 256], color='green')\n",
        "plt.xlabel('Bins 8')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "DUfbg95_YH0Z",
        "outputId": "eb36af06-9d3a-485c-f63a-cb98e2cda795"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bluech.ravel(), 256, [0, 256], color='green')\n",
        "plt.xlabel('Bins 256')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "xG1_62ViYJ_4",
        "outputId": "f4f52462-4ae3-479e-d5ef-1b40c29a7dbd"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#red channel\n",
        "\n",
        "redch = image[:,:,2]\n",
        "cv2_imshow(redch)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "3taVCEZOYMxK",
        "outputId": "d8f34b92-9be7-4783-ab6d-9c711efa814c"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC42A039610>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(redch.ravel(), 256, [0, 256], color='red')\n",
        "plt.xlabel('Bins 256')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "DYzZXAh-YPSX",
        "outputId": "d41bfb81-343e-4e19-d2fc-6f20d7523f70"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(redch.ravel(), 32, [0, 256], color='red')\n",
        "plt.xlabel('Bins 8')\n",
        "plt.ylabel('Num of Pixel')\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 279
        },
        "id": "CWTQlSneYQdX",
        "outputId": "ad2d9213-3d86-4baa-d63d-31ecd24bccc9"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(redch.ravel(), 16, [0, 256], color='red')\n",
        "plt.xlabel('Bins 16')\n",
        "plt.ylabel('Num of Pixel')"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 296
        },
        "id": "HCnK9bfjYU8k",
        "outputId": "ed60aa1c-e9e3-4754-93f3-c5c7c03d0b08"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "Text(0, 0.5, 'Num of Pixel')"
            ]
          },
          "metadata": {},
          "execution_count": 37
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(redch.ravel(), 8, [0, 256], color='red')\n",
        "plt.xlabel('Bins 32')\n",
        "plt.ylabel('Num of Pixel')"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 298
        },
        "id": "GtkXlPZiYWON",
        "outputId": "21556349-5d94-4734-a518-c9901aefec2e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "Text(0, 0.5, 'Num of Pixel')"
            ]
          },
          "metadata": {},
          "execution_count": 38
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(redch.ravel(), 4, [0, 256], color='red')\n",
        "plt.xlabel('Bins 4')\n",
        "plt.ylabel('Num of Pixel')"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 299
        },
        "id": "8Ofp2zn4YYrR",
        "outputId": "53f7070b-a9e1-4e45-8882-480dce2b896f"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "Text(0, 0.5, 'Num of Pixel')"
            ]
          },
          "metadata": {},
          "execution_count": 39
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "gray_image = cv.cvtColor(image, cv.)\n",
        "cv2_imshow(gray_image)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "MWxuj1bdYbY2",
        "outputId": "a30d6339-0830-4933-9b5a-b30a7668e54c"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC429C1F650>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(gray_image.ravel(), bins = 256, range = [0,256])\n",
        "plt.show()\n",
        "\n",
        "\n",
        "print(gray_image.size)\n",
        "print(gray_image.shape)\n",
        "print(gray_image.dtype)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 317
        },
        "id": "rkVGlpcYYepN",
        "outputId": "55df1b0f-1a73-47db-9345-a1131ded669f"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        },
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "50625\n",
            "(225, 225)\n",
            "uint8\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(gray_image.ravel(), bins = 4, range = [0,256])\n",
        "plt.show()\n",
        "\n",
        "\n",
        "print(gray_image.size)\n",
        "print(gray_image.shape)\n",
        "print(gray_image.dtype)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 321
        },
        "id": "SEUdEuXmYhiZ",
        "outputId": "f596ebcf-1b3d-4187-8a16-82dada250966"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        },
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "50625\n",
            "(225, 225)\n",
            "uint8\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "invert_gray = 255 - gray_image\n",
        "cv2_imshow(invert_gray)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "flW9VerRYoOZ",
        "outputId": "b8193384-cddd-4e29-b13c-2e6791e0bcdc"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC429F4E450>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "AvhenbKuYqJo",
        "outputId": "dd2126bb-9698-4678-86fe-9e23eec135f2"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "bright_image = (100.0/255)*gray_image + 100\n",
        "cv2_imshow(bright_image)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "vGclJirjYt5z",
        "outputId": "a6844304-6963-4b7b-ef80-b03f4662c3fd"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC429FBAB90>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(bright_image.ravel(), bins = 256, range = [0,256])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "EI8sttcRYw1c",
        "outputId": "5c07b725-c9b9-4870-dde2-8c8a4fbfd0e2"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "darken_image = 255.0*(gray_image/255.0)**2\n",
        "cv2_imshow(darken_image)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 242
        },
        "id": "1cQRf2BmYz8N",
        "outputId": "e5211e87-ac24-446d-eea0-fb6ee2c9f65e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<PIL.Image.Image image mode=L size=225x225 at 0x7FC42A186C90>"
            ],
            "image/png": "...\n"
          },
          "metadata": {}
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.hist(darken_image.ravel(), bins = 256, range = [0,256])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "7QmWfUNMY5Nq",
        "outputId": "057a7e31-8c1a-4fea-dfb1-7279609c198e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
                }
          }
        ],
# Out:
#   File "<ipython-input-32-140ecfa26703>", line 1285
#     ],
#       ^
# SyntaxError: unexpected EOF while parsing
